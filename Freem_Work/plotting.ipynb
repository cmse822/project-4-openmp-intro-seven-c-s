# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Reading data
master_data = pd.read_csv("MMM_20x20.csv")
master_data = master_data.to_numpy()

# Removing first 20 entries of each timing to ignore first time load up costs
mean_data =  np.mean(master_data[21:-1, :], 0)
num_threads = np.array([1, 2, 4, 8, 12, 16, 20, 24])

plt.plot(num_threads, mean_data)
plt.xlabel("Thread Count")
plt.ylabel("Time to Compute (s)")
plt.title("Time to Compute MMM N=20")
plt.savefig("plot_N20.png")

plt.clf()
plt.cla()
plt.plot(num_threads, mean_data[0] / mean_data)
plt.xlabel("Thread Count")
plt.ylabel("Speedup (Serial / Parallel)")
plt.title("Speedup Analysis N=20")
plt.savefig("plot_speedup_N20.png")

# %%
# Reading data
master_data = pd.read_csv("MMM_100x100.csv")
master_data = master_data.to_numpy()

# Removing first 20 entries of each timing to ignore first time load up costs
mean_data =  np.mean(master_data[21:-1, :], 0)
num_threads = np.array([1, 2, 4, 8, 12, 16, 20, 24])

plt.plot(num_threads[1:-1], mean_data[1:-1])
plt.xlabel("Thread Count")
plt.ylabel("Time to Compute (s)")
plt.title("Time to Compute MMM N=100")
plt.savefig("plot_N100.png")

plt.clf()
plt.cla()
plt.plot(num_threads[1:-1], mean_data[1] / mean_data[1:-1])
plt.xlabel("Thread Count")
plt.ylabel("Speedup (Serial / Parallel)")
plt.title("Speedup Analysis N=100")
plt.savefig("plot_speedup_N100.png")

# %%
# Reading data
master_data = pd.read_csv("MMM_1000x1000.csv")
master_data = master_data.to_numpy()

# Removing first 20 entries of each timing to ignore first time load up costs
mean_data =  np.mean(master_data[21:-1, :], 0)
num_threads = np.array([1, 2, 4, 8, 12, 16, 20, 24])

plt.plot(num_threads, mean_data)
plt.xlabel("Thread Count")
plt.ylabel("Time to Compute (s)")
plt.title("Time to Compute MMM N=1000")
plt.savefig("plot_N1000.png")

plt.clf()
plt.cla()
plt.plot(num_threads, mean_data[0] / mean_data)
plt.xlabel("Thread Count")
plt.ylabel("Speedup (Serial / Parallel)")
plt.title("Speedup Analysis N=1000")
plt.savefig("plot_speedup_N1000.png")
